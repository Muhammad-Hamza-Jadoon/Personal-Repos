# %% [markdown]
# # String

# %%
Given an array of integers nums and an integer target, return indices of the two numbers such that they add up to target.

You may assume that each input would have exactly one solution, and you may not use the same element twice.

You can return the answer in any order.

 

Example 1:

Input: nums = [2,7,11,15], target = 9
Output: [0,1]
Explanation: Because nums[0] + nums[1] == 9, we return [0, 1].
Example 2:

Input: nums = [3,2,4], target = 6
Output: [1,2]
Example 3:

Input: nums = [3,3], target = 6
Output: [0,1]


class Solution(object):
    def twoSum(self, nums, target):
        """
        :type nums: List[int]
        :type target: int
        :rtype: List[int]
        """
        complement_dict = {}
        for i, num in enumerate(nums):
            complement = target - num
            if complement in complement_dict:
                return [complement_dict[complement], i]
            complement_dict[num] = i
        return []


or

    def twoSum(self, nums, target):
      for i in range(len(nums)):
        for j in range(i + 1, len(nums)):
          if nums[i] + nums[j] == target:
            return [i, j]

# %%
Given a string s, find the length of the longest 
substring
 without repeating characters.

 

Example 1:

Input: s = "abcabcbb"
Output: 3
Explanation: The answer is "abc", with the length of 3.
Example 2:

Input: s = "bbbbb"
Output: 1
Explanation: The answer is "b", with the length of 1.
Example 3:

Input: s = "pwwkew"
Output: 3
Explanation: The answer is "wke", with the length of 3.
Notice that the answer must be a substring, "pwke" is a subsequence and not a substring.


class Solution(object):
  def lengthOfLongestSubstring(self, s):
    """
    :type s: str
    :rtype: int
    """
    longest = 0
    start = -1  # Index of the start of the current substring
    char_index = {}  # Dictionary to store last seen index of each character

    for i, char in enumerate(s):
      # If the character is already seen within the current substring
      if char in char_index and char_index[char] > start:
        # Update start to skip past the previous occurrence
        start = char_index[char]
      # Update the last seen index for the current character
      char_index[char] = i
      # Update longest if the current substring is longer
      longest = max(longest, i - start)

    return longest

# %%
ou are given a string s and an integer k. You can choose any character of the string and change it to any other uppercase English character. 
You can perform this operation at most k times.

Return the length of the longest substring containing the same letter you can get after performing the above operations.

 

Example 1:

Input: s = "ABAB", k = 2
Output: 4
Explanation: Replace the two 'A's with two 'B's or vice versa.
Example 2:

Input: s = "AABABBA", k = 1
Output: 4
Explanation: Replace the one 'A' in the middle with 'B' and form "AABBBBA".
The substring "BBBB" has the longest repeating letters, which is 4.
There may exists other ways to achieve this answer too.
 

Constraints:

1 <= s.length <= 105
s consists of only uppercase English letters.
0 <= k <= s.length



class Solution(object):
  def characterReplacement(self, s, k):
    """
    :type s: str
    :type k: int
    :rtype: int
    """
    longest = 0
    start = 0
    max_char_count = 0
    char_count = {}

    for i, char in enumerate(s):
      # Update character count dictionary
      char_count[char] = char_count.get(char, 0) + 1
      # Update max_char_count for the current window
      max_char_count = max(max_char_count, char_count[char])

      # Shrink the window while exceeding allowed replacements
      while i - start + 1 - max_char_count > k:
        char_count[s[start]] -= 1
        start += 1

      # Update longest with current window size
      longest = max(longest, i - start + 1)

    return longest

# %%
Given two strings s and t, return true if t is an anagram of s, and false otherwise.

An Anagram is a word or phrase formed by rearranging the letters of a different word or phrase, typically using all the original letters exactly once.

 

Example 1:

Input: s = "anagram", t = "nagaram"
Output: true
Example 2:

Input: s = "rat", t = "car"
Output: false
 

Constraints:

1 <= s.length, t.length <= 5 * 104
s and t cons

class Solution(object):
  def isAnagram(self, s, t):
    """
    :type s: str
    :type t: str
    :rtype: bool
    """
    return sorted(s) == sorted(t)

# %% [markdown]
# # pandas/csv

# %%
1. Load the CSV data:

Python
import pandas as pd
import numpy as np

# Assuming your CSV file is named 'data.csv'
data = pd.read_csv('data.csv')
Use code with caution.
content_copy



2. Filter data based on conditions:

Python
# Filter reviews with rating above 7
high_rated_reviews = data[data['rating'] > 7]

# Filter products with specific names (case-sensitive)
specific_products = data[data['product_name'].isin(['Product A', 'Product B'])]

# Filter products containing a specific word (case-insensitive)
products_with_word = data[data['product_name'].str.contains('keyword', case=False)]
Use code with caution.
content_copy




3. Descriptive statistics:

Python
# Get basic statistics for numeric columns
data.describe()

# Calculate mean rating
average_rating = data['rating'].mean()

# Find minimum and maximum values in multiple columns
min_values = data[['price', 'quantity']].min()
max_values = data[['price', 'quantity']].max()
Use code with caution.
content_copy




4. Group and aggregate data:

Python
# Average rating by product category
average_rating_by_category = data.groupby('category')['rating'].mean()

# Count occurrences of each product name
product_counts = data['product_name'].value_counts()
Use code with caution.
content_copy




5. Handle missing values:

Python
# Check for missing values
data.isnull().sum()

# Drop rows with missing values (not recommended)
# data.dropna(inplace=True)

# Impute missing values (e.g., with mean)
data['price'].fillna(data['price'].mean(), inplace=True)
Use code with caution.
content_copy





6. String manipulation:

Python
# Convert a column to uppercase
data['product_name'] = data['product_name'].str.upper()

# Remove leading/trailing whitespaces
data['review_text'] = data['review_text'].str.strip()

# Extract specific parts from a string (assuming a specific format)
data['extracted_value'] = data['some_column'].str.split('-').str[1]
Use code with caution.
content_copy




7. Date and time operations (if applicable):

Python
# Assuming a 'date' column
data['date'] = pd.to_datetime(data['date'])

# Filter data for a specific date range
recent_data = data[(data['date'] >= '2024-07-01') & (data['date'] <= '2024-07-05')]

# Calculate time differences (assuming 'purchase_time' and 'delivery_time' columns)
data['delivery_time_diff'] = data['delivery_time'] - data['purchase_time']
Use code with caution.
content_copy




8. Working with NumPy arrays:

Python
# Convert DataFrame to NumPy array
data_array = data.to_numpy()

# Perform array operations (assuming numeric data)
average_price = np.mean(data_array[:, 2])  # Assuming price is in the 3rd column
Use code with caution.
content_copy




9. Merging and joining DataFrames:

Python
# Assuming you have another CSV file named 'customer_data.csv'
customer_data = pd.read_csv('customer_data.csv')

# Merge based on a common column (e.g., 'customer_id')
merged_data = pd.merge(data, customer_data, on='customer_id')

# Join DataFrames (various options based on relationships)
joined_data = data.set_index('product_id').join(customer_data.set_index('customer_id'), how='outer')
Use code with caution.
content_copy





10. Exporting data:

Python
# Save DataFrame as a new CSV file
high_rated_reviews.to_csv('high_rated_reviews.csv', index=False)

# Save DataFrame as a different file format (e.g., Excel)
data.to_excel('data.xlsx', index=False)

# %% [markdown]
# # SQL

# %%
1. Filtering Data:

SQL
SELECT * FROM reviews WHERE rating > 7;  -- Filter reviews with rating above 7
SELECT * FROM products WHERE product_name IN ('Product A', 'Product B');  -- Filter specific products (case-sensitive)
SELECT * FROM products WHERE product_name LIKE '%keyword%';  -- Filter products containing a word (case-insensitive)
Use code with caution.
content_copy
2. Descriptive Statistics:

SQL
SELECT AVG(rating) AS average_rating FROM reviews;  -- Calculate average rating
SELECT MIN(price), MAX(quantity) FROM products;  -- Find minimum and maximum values in multiple columns
Use code with caution.
content_copy
3. Grouping and Aggregation:

SQL
SELECT category, AVG(rating) AS average_rating_by_category
FROM reviews
GROUP BY category;  -- Average rating by product category

SELECT product_name, COUNT(*) AS product_count
FROM products
GROUP BY product_name;  -- Count occurrences of each product name
Use code with caution.
content_copy
4. Handling Missing Values:

SQL
SELECT * FROM reviews WHERE rating IS NOT NULL;  -- Filter rows with non-null rating
UPDATE products SET price = (SELECT AVG(price) FROM products) WHERE price IS NULL;  -- Impute missing price with average
Use code with caution.
content_copy
5. String Manipulation (limited in SQL):

SQL
SELECT UPPER(product_name) AS uppercase_name FROM products;  -- Convert product name to uppercase (may vary by database)
SELECT TRIM(review_text) AS trimmed_review FROM reviews;  -- Remove leading/trailing whitespaces (may vary by database)
Use code with caution.
content_copy
6. Date and Time Operations (if applicable):

SQL
SELECT * FROM orders WHERE order_date >= '2024-07-01' AND order_date <= '2024-07-05';  -- Filter data for a specific date range
'''
SELECT delivery_time - purchase_time AS delivery_time_diff FROM orders;  -- Calculate time difference (assuming columns exist)
Use code with caution.
content_copy
7. Joining Tables:

SQL
SELECT r.rating, p.product_name, c.customer_city
FROM reviews r
INNER JOIN products p ON r.product_id = p.id
LEFT JOIN customers c ON r.customer_id = c.id;  -- Join reviews, products, and customers (example)
Use code with caution.
content_copy
8. Subqueries and Nested Queries:

SQL
SELECT product_name, rating
FROM products p
WHERE id IN (
  SELECT product_id FROM reviews WHERE rating = (SELECT MAX(rating) FROM reviews)
);  -- Find product with highest average rating using subquery
Use code with caution.
content_copy
9. Sorting and Limiting Results:

SQL
SELECT * FROM reviews ORDER BY rating DESC LIMIT 10;  -- Sort reviews by rating (descending) and limit to top 10
Use code with caution.
content_copy
10. Data Manipulation (CRUD - Create, Read, Update, Delete):

SQL
INSERT INTO products (product_name, price) VALUES ('New Product', 19.99);  -- Insert a new product

UPDATE reviews SET rating = rating + 1 WHERE rating < 5;  -- Update rating for reviews below 5

DELETE FROM orders WHERE order_date < '2023-01-01';  -- Delete old orders (be ca

# %% [markdown]
# info

# %%
AlexNet, VGGNet, and GoogLeNet/Inception are earlier CNN architectures that focused on increasing depth and complexity to improve performance. 
They introduced innovations like convolutional layers, max-pooling, and ReLU activation functions.

ResNet and DenseNet, on the other hand, aimed to address the limitations of earlier architectures by introducing new connectivity patterns. 
ResNet introduced residual connections to ease training and improve performance, while DenseNet introduced dense connections to reuse features 
and reduce parameters.
    
MobileNet and ShuffleNet are more recent architectures that focus on efficiency and computational resources. 
They use depthwise separable convolutions, channel shuffle operations, and other techniques to reduce parameters and computations 
while maintaining performance.
