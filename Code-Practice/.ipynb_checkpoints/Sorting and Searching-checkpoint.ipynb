# %%
def bubble_sort(arr):
    n = len(arr)
    for i in range(n):

        print("\nLoop ", 0, n-i-1)
        print(arr)
        
        bool = False
        for j in range(0, n-i-1):
            print(arr[j]," > ", arr[j+1])
            if arr[j] > arr[j+1]:
                arr[j], arr[j+1] = arr[j+1], arr[j]
                print("\nswap [",arr[j],"] with [", arr[j+1],"]")
                print("sorted array : ",arr,"\n")
                bool = True
                
        if bool == False: return arr
                
    return arr


arr = [10,2,4,3,9,8,7,5,6,1]
bubble_sort(arr)
# Out:
# Loop  0 9
# [10, 2, 4, 3, 9, 8, 7, 5, 6, 1]
# 10  >  2
#
# swap [ 2 ] with [ 10 ]
# sorted array :  [2, 10, 4, 3, 9, 8, 7, 5, 6, 1]
#
# 10  >  4
#
# swap [ 4 ] with [ 10 ]
# sorted array :  [2, 4, 10, 3, 9, 8, 7, 5, 6, 1]
#
# 10  >  3
#
# swap [ 3 ] with [ 10 ]
# sorted array :  [2, 4, 3, 10, 9, 8, 7, 5, 6, 1]
#
# 10  >  9
#
# swap [ 9 ] with [ 10 ]
# sorted array :  [2, 4, 3, 9, 10, 8, 7, 5, 6, 1]
#
# 10  >  8
#
# swap [ 8 ] with [ 10 ]
# sorted array :  [2, 4, 3, 9, 8, 10, 7, 5, 6, 1]
#
# 10  >  7
#
# swap [ 7 ] with [ 10 ]
# sorted array :  [2, 4, 3, 9, 8, 7, 10, 5, 6, 1]
#
# 10  >  5
#
# swap [ 5 ] with [ 10 ]
# sorted array :  [2, 4, 3, 9, 8, 7, 5, 10, 6, 1]
#
# 10  >  6
#
# swap [ 6 ] with [ 10 ]
# sorted array :  [2, 4, 3, 9, 8, 7, 5, 6, 10, 1]
#
# 10  >  1
#
# swap [ 1 ] with [ 10 ]
# sorted array :  [2, 4, 3, 9, 8, 7, 5, 6, 1, 10]
#
#
# Loop  0 8
# [2, 4, 3, 9, 8, 7, 5, 6, 1, 10]
# 2  >  4
# 4  >  3
#
# swap [ 3 ] with [ 4 ]
# sorted array :  [2, 3, 4, 9, 8, 7, 5, 6, 1, 10]
# ...

# %%
def insertion_sort(arr):
    n = len(arr)
    for i in range(1, n):
        
        key = arr[i]
        j = i - 1
        print("\n",arr)
        # print("i = ",i, "| j = ",j, "| key = ", key, "| arr[j] = ", arr[j])

        print("comparison between : ",key, " < ", arr[j])
        while j >= 0 and key < arr[j]:
            # print()
            arr[j + 1] = arr[j]
            print("---Loop---", arr)
            j -= 1
            print("comparison between : ",key, " < ", arr[j])
        arr[j + 1] = key
        print("                                     final array : ",arr)
    return arr

arr = [1,2,4,3,9,8,7,5,6,10]
insertion_sort(arr)
# Out:
#  [1, 2, 4, 3, 9, 8, 7, 5, 6, 10]
# comparison between :  2  <  1
#                                      final array :  [1, 2, 4, 3, 9, 8, 7, 5, 6, 10]
#
#  [1, 2, 4, 3, 9, 8, 7, 5, 6, 10]
# comparison between :  4  <  2
#                                      final array :  [1, 2, 4, 3, 9, 8, 7, 5, 6, 10]
#
#  [1, 2, 4, 3, 9, 8, 7, 5, 6, 10]
# comparison between :  3  <  4
# ---Loop--- [1, 2, 4, 4, 9, 8, 7, 5, 6, 10]
# comparison between :  3  <  2
#                                      final array :  [1, 2, 3, 4, 9, 8, 7, 5, 6, 10]
#
#  [1, 2, 3, 4, 9, 8, 7, 5, 6, 10]
# comparison between :  9  <  4
#                                      final array :  [1, 2, 3, 4, 9, 8, 7, 5, 6, 10]
#
#  [1, 2, 3, 4, 9, 8, 7, 5, 6, 10]
# comparison between :  8  <  9
# ---Loop--- [1, 2, 3, 4, 9, 9, 7, 5, 6, 10]
# comparison between :  8  <  4
#                                      final array :  [1, 2, 3, 4, 8, 9, 7, 5, 6, 10]
#
#  [1, 2, 3, 4, 8, 9, 7, 5, 6, 10]
# comparison between :  7  <  9
# ...
